# %%
import xml.etree.ElementTree as ElementTree
import os, sys, csv
from urllib.request import urlopen
import pandas as pd 
import numpy as np
import requests
import xml.etree.ElementTree as ET

class XML2DataFrame:
    root = ''
    def __init__(self, xml_data):
        self.root = ET.XML(xml_data)


    def parse_root(self, root):
        return [self.parse_element(child) for child in iter(root)]

    def parse_element(self, element, parsed=None):
        if parsed is None:
            parsed = dict()
        for key in element.keys():
            parsed[key] = element.attrib.get(key)
        if element.text:
            parsed[element.tag] = element.text
        for child in list(element):
            self.parse_element(child, parsed)
        return parsed

    def process_data(self,root):
        structure_data = self.parse_root(root)
        return pd.DataFrame(structure_data)

# %%
def single_quote(s1):
    return "'%s'" % s1
    
user_agent_url = 'https://eeas.europa.eu/topics/sanctions-policy/8442/consolidated-list-of-sanctions_en'
fetched_data = requests.get(user_agent_url).content

# %%
#user_agent_url = 'https://eeas.europa.eu/topics/sanctions-policy/8442/consolidated-list-of-sanctions_en'
#fetched_data = requests.get(user_agent_url).content
from bs4 import BeautifulSoup
soup = BeautifulSoup(fetched_data)
import re
links = soup.findAll('a', attrs={'href': re.compile("xmlFullSanctionsList")})
for link in links:
    url = link.text
# Out:
# c:\program files\python35\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file c:\program files\python35\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import urllib
urllib.request.urlretrieve(url, 'temp.csv')
#from lxml import etree
#xml = etree.parse('temp.csv')
# Out:
# ('temp.csv', <http.client.HTTPMessage at 0x2fd5782be0>)

# %%
with open('temp.csv','r', encoding="utf8") as f:
    fetched_data = f.read()

# %%
root = ET.XML(fetched_data)
name_tags = ['Id','WHOLENAME','FUNCTION']
alt_name_tags = ['Id','WHOLENAME']

# %%
xml2df = XML2DataFrame(fetched_data)

# %%
for attribute in xml2df.root:
    for indiv in attribute.iter('sanctionEntity'):
        df = xml2df.process_data(indiv)

# %%
for attribute in xml2df.root:
git checkout
# Out:
# [<Element '{http://eu.europa.ec/fpi/fsd/export}regulation' at 0x0000002FB569A598>, <Element '{http://eu.europa.ec/fpi/fsd/export}subjectType' at 0x0000002FB5B40048>, <Element '{http://eu.europa.ec/fpi/fsd/export}nameAlias' at 0x0000002FB5B40B38>, <Element '{http://eu.europa.ec/fpi/fsd/export}birthdate' at 0x0000002FD4288318>, <Element '{http://eu.europa.ec/fpi/fsd/export}identification' at 0x0000002FBF461778>]
# [<Element '{http://eu.europa.ec/fpi/fsd/export}remark' at 0x0000002FD647CEA8>, <Element '{http://eu.europa.ec/fpi/fsd/export}regulation' at 0x0000002FD647C7C8>, <Element '{http://eu.europa.ec/fpi/fsd/export}subjectType' at 0x0000002FDADC7188>, <Element '{http://eu.europa.ec/fpi/fsd/export}nameAlias' at 0x0000002FDADC7408>, <Element '{http://eu.europa.ec/fpi/fsd/export}birthdate' at 0x0000002FD57256D8>]
# ...

# %%
for indiv in root.iter('sanctionEntity'):
    id = indiv.find('ID').text + '_' + str(i)
    results_indiv[id] = []
    for f in range(1, len(name_tags)):
        addr = ''
        if alias.find(name_tags[f]) is None:
            pass 
        else:
            addr += str(alias.find(name_tags[f]).text).replace('\n','')
    results_indiv [id] = addr

for indiv in root.iter('ENTITY'):
    for i, alias in enumerate(indiv.findall('ENTITY_ADDRESS')):
        id = indiv.find('DATAID').text + '_' + str(i)
        results_ent[id] = []
        for f in range(1, len(alt_name_tags)):
            addr = ''
            if alias.find(alt_name_tags[f]) is None:
                pass 
            else:
                addr += str(alias.find(alt_name_tags[f]).text).replace('\n','')
        results_ent  [id] = addr

# %%
                      
df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())
df[df_obj.columns] = df_obj.apply(lambda x: x.str.replace("-0-", ""))
df[df_obj.columns] = df_obj.apply(lambda x: x.str.replace("\n", ""))
df[df_obj.columns] = df_obj.apply(lambda x: x.str.replace("'", "\''"))
df = df.replace(np.nan, '', regex=True)
df.head()
#df ['DATAID'] = df ['DATAID'].apply (lambda x : x.split("_")[0])
#df ['ID'] = df ['DATAID'].apply(lambda x: 'EU'.str(x))
# Out:
#       DATAID                                            ADDRESS
# 0  6908473_1  United Kingdom of Great Britain and Northern I...
# 1  6908416_0                                               None
# 2  6908470_0                                              Qatar
# 3  6908424_0                                               None
# 4  6908533_0                                              Libya

# %%
for index, row in df.iterrows():
    ID1 = single_quote('') 
    query_value = "( " + single_quote(row['ID']) + ", " + ID1 + ", " +single_quote(row['ADDRESS'])+ ", "+single_quote('UN') + ") "
    insert_command = "insert into [ref].[sanctions_addresses_new]  (Id, ID1,Address,source) values"
    query = '{} {}'.format(insert_command, query_value)
    print("Index : " )
    print(index)
    print(query)
    stat,message = db_insert(query)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files\python35\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2482             try:
# -> 2483                 return libts.get_value_box(s, key)
#    2484             except IndexError:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18843)()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18477)()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-396-9e5c77c45f7d> in <module>()
#       1 for index, row in df.iterrows():
#       2     ID1 = single_quote('')
# ...

# %%
df.head()
# Out:
#       DATAID                                            ADDRESS
# 0  6908473_1  United Kingdom of Great Britain and Northern I...
# 1  6908416_0                                               None
# 2  6908470_0                                              Qatar
# 3  6908424_0                                               None
# 4  6908533_0                                              Libya
